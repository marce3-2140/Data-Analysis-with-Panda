# %% [markdown]
# <a href="https://colab.research.google.com/github/marce3-2140/Data-Analysis-with-Panda/blob/main/bykes_RailsToTrails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lida Marcela Giraldo**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from datetime import datetime

# %%
filename = '/content/drive/MyDrive/CodingDojo/Fundamentals/Week2/Cargas/RailsToTrails_National Count Data_week.xlsx'
bike_df = pd.read_excel(filename)
bike_df.head(3)
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN

# %%
#Leer datos como en un excel
file_name = '/content/drive/MyDrive/CodingDojo/Fundamentals/Week2/Cargas/RailsToTrails_National Count Data_week.xlsx'
xl_file = pd.ExcelFile(file_name)
dfs = {sheet_name: xl_file.parse(sheet_name)
        for sheet_name in xl_file.sheet_names}

bike_df = dfs['Total Count data (31 counters)']
bike_df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
# 3                       83809          NaN          0.105645  110.564504
# 4                       94738          NaN          0.249166  124.916602
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# ...

# %% [markdown]
# **1. Solo seleccione los datos despues del 31 de julio de 2020**

# %%
bike_df_fecha =bike_df[bike_df['Week of']>'2020-07-31']
bike_df_fecha.head(3)
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                      167679
# 31   Week 32 2020-08-03                      180605
# 32   Week 33 2020-08-10                      191450
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                       183546          NaN          0.094627    1.094627
# 31                      239827          NaN          0.330000  132.790897
# 32                      219279          NaN          0.150000  114.535910
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0          NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN

# %%
date_time_str = '2020-07-31'
date_time_obj = datetime.strptime(date_time_str, '%Y-%m-%d')
result = bike_df[bike_df['Week of']> date_time_obj]
result
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                      167679
# 31   Week 32 2020-08-03                      180605
# 32   Week 33 2020-08-10                      191450
# 33   Week 34 2020-08-17                      168754
# 34   Week 35 2020-08-24                      176624
# 35   Week 36 2020-08-31                      184806
# 36   Week 37 2020-09-07                      157345
# 37   Week 38 2020-09-14                      152527
# 38   Week 39 2020-09-21                      141072
# 39   Week 40 2020-09-28                      135881
# 40   Week 41 2020-10-05                      132239
# 41   Week 42 2020-10-12                      110816
# 42   Week 43 2020-10-19                      110761
# 43   Week 44 2020-10-26                      109795
# 44   Week 45 2020-11-02                      109766
# 45   Week 46 2020-11-09                       86824
# 46   Week 47 2020-11-16                       88122
# ...

# %% [markdown]
# **2. Solo seleccionen los datos donde la columna “Change 2019-2020” es superior al 100 % (superior 1).**

# %%
sup_1 = bike_df[bike_df['Change 2019-2020']>1]
sup_1
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 7     Week 8 2020-02-17                       69492
# 11   Week 12 2020-03-16                      125440
# 12   Week 13 2020-03-23                      136330
# 13   Week 14 2020-03-30                      118784
# 14   Week 15 2020-04-06                      132033
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 7                       149876          NaN          1.156737  215.673747
# 11                      367795          NaN          1.932039  293.203922
# 12                      372783          NaN          1.730000  273.441649
# 13                      280728          NaN          1.360000  236.334860
# 14                      419160          NaN          2.170000  317.466088
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 7          NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# ...

# %% [markdown]
# **3. ¡Únanlos! ¿Hubo alguna semana en la segunda mitad del año (después del 31 de julio de 2020) en la que el cambio fuera superior al 100 %?**

# %%
sup_1['Week of']>'2020-07-31'
# Out:
# 7     False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: Week of, dtype: bool

# %%
#resetear el index
'''
.reset_index(drop=True)
'''
# Out:
# '\n.reset_index(drop=True)\n'

# %% [markdown]
# # Actividad de practica: Renombrar y eliminar datos faltantes

# %% [markdown]
# **1. Eliminen las columnas innecesarias**

# %%
bike_df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
# 3                       83809          NaN          0.105645  110.564504
# 4                       94738          NaN          0.249166  124.916602
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# ...

# %%
#Remove Duplicates if there are
bike_df.duplicated().sum()
# Out:
# 0

# %%
#nunique tell us how many unique values are in each column.
bike_df.nunique()
# Out:
# Timeframe                     52
# Week of                       52
#  2019 counts (31 counters)    52
#  2020 counts (31 counters)    52
# 2021 Counts                    0
# Change 2019-2020              44
# Unnamed: 6                    52
# Unnamed: 7                     0
# Unnamed: 8                     1
# Unnamed: 9                     1
# dtype: int64

# %%
#rennombrar la columna Unnamed 6 a percent_change
bike_df = bike_df.rename(columns={'Unnamed: 6': 'percent_change'})
bike_df.head(3)
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  percent_change  \
# 0                      183546          NaN          0.094627        1.094627
# 1                       97140          NaN          0.179743      117.974253
# 2                       75782          NaN          0.216112      121.611169
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN

# %%
#Remove Unnecessary Columns
bike_df.columns
# Out:
# Index(['Timeframe', 'Week of', ' 2019 counts (31 counters)',
#        ' 2020 counts (31 counters)', '2021 Counts', 'Change 2019-2020',
#        'percent_change', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
valores_faltantes = bike_df.info()
valores_faltantes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     float64
#  6   percent_change              52 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      float64
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 4.2+ KB

# %%
#Se decide quitar las columnas sin nombre y sin la mayoria de datos a excepcion
#2021 Counts.
bike_df = bike_df.drop(columns=['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'])
bike_df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  percent_change
# 0                      183546          NaN          0.094627        1.094627
# 1                       97140          NaN          0.179743      117.974253
# 2                       75782          NaN          0.216112      121.611169
# 3                       83809          NaN          0.105645      110.564504
# 4                       94738          NaN          0.249166      124.916602

# %% [markdown]
# **2. ¿Cuántos valores faltantes hay en el conjunto de datos? ¿En que columnas están?**

# %% [markdown]
# Identificar los valores faltantes se hizo en la pregunta numero 1 para poder determinar que columnas eliminar, asi antes de eliminar las columnas los valores faltantes estaban en:
#
# 1. 2021 Counts                    (0 non-null)
# 2. Unnamed: 7                     (0 non-null)
# 3. Unnamed: 8                     (1 non-null)
# 4. Unnamed: 9                     (1 non-null)

# %%
#Encontrar valores nulos
bike_df.isnull().sum()
# Out:
# Timeframe                      0
# Week of                        0
#  2019 counts (31 counters)     0
#  2020 counts (31 counters)     0
# 2021 Counts                   52
# Change 2019-2020               0
# percent_change                 0
# dtype: int64

# %% [markdown]
# Aun quedan valores nulos en la columna de 2021 counts

# %% [markdown]
# **3. Rellenar los valores faltantes en la columna 2021 Counts con 0.**

# %%
#identificamos que datos tiene la columna
bike_df['2021 Counts'].value_counts()
# Out:
# Series([], Name: 2021 Counts, dtype: int64)

# %%
bike_df['2021 Counts'].fillna(0, inplace=True)
bike_df['2021 Counts'].value_counts()
# Out:
# 0.0    52
# Name: 2021 Counts, dtype: int64

# %% [markdown]
# 4. **Optional/Bonus:** There is a challenging but common problem in the name for the 2019 counts column. Can you find it? If so, Rename the 2019 counts (31 counters) column to "counts_2019" (a more Pythonic column name).

# %%
# This is challenging because there is an extra space before the column name!
# ' 2019 counts (31 counters)'
# This is hard to see/notice at first glance and requires extra attention to the name
# It is common to have little issues like this in your column names!
bike_df.columns
# Out:
# Index(['Timeframe', 'Week of', ' 2019 counts (31 counters)',
#        ' 2020 counts (31 counters)', '2021 Counts', 'Change 2019-2020',
#        'percent_change'],
#       dtype='object')

# %%
bike_df = bike_df.rename(columns={' 2019 counts (31 counters)': 'counts_2019'})
bike_df.head()
# Out:
#   Timeframe    Week of  counts_2019   2020 counts (31 counters)  2021 Counts  \
# 0    Week 1 2020-12-30       167679                      183546          0.0
# 1    Week 2 2020-01-06        82340                       97140          0.0
# 2    Week 3 2020-01-13        62315                       75782          0.0
# 3    Week 4 2020-01-20        75801                       83809          0.0
# 4    Week 5 2020-01-27        75841                       94738          0.0
#
#    Change 2019-2020  percent_change
# 0          0.094627        1.094627
# 1          0.179743      117.974253
# 2          0.216112      121.611169
# 3          0.105645      110.564504
# 4          0.249166      124.916602
