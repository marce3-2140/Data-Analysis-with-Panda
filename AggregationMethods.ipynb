# %% [markdown]
# <a href="https://colab.research.google.com/github/marce3-2140/Data-Analysis-with-Panda/blob/main/AggregationMethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metodos de agregacion en Pandas
#
# 1. **Comprender y utilizar metodos de agregacion**
# 2. **Utilizar df.describe() para obtener estadisticas resumidas comunes**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/CodingDojo/Fundamentals/Week2/Cargas/mortgages.csv'
df = pd.read_csv(filename)

# %% [markdown]
# # Filtrar Datos
#
# 1. Obtengan los datos de la tabla de pagos de la hipoteca a 30 años con el 3% de abril.

# %%
mortgage_filter = df['Mortgage Name']=='30 Year'
interest_filter = df['Interest Rate']==0.03
df = df.loc[mortgage_filter & interest_filter, :]
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1         400000.00    1686.42        1000.00          686.42
# 1        2         399313.58    1686.42         998.28          688.14
# 2        3         398625.44    1686.42         996.56          689.86
# 3        4         397935.58    1686.42         994.83          691.59
# 4        5         397243.99    1686.42         993.10          693.32
# ..     ...               ...        ...            ...             ...
# 355    356           8364.12    1686.42          20.91         1665.51
# 356    357           6698.61    1686.42          16.74         1669.68
# 357    358           5028.93    1686.42          12.57         1673.85
# 358    359           3355.08    1686.42           8.38         1678.04
# 359    360           1677.04    1686.42           4.19         1682.23
#
#      New Balance Mortgage Name  Interest Rate
# 0      399313.58       30 Year           0.03
# ...

# %% [markdown]
# # Metodos de Agregacion
#
#
#
# ```
# 1. sum        -suma de valores
# 2. cumsum     -suma acumulativa
# 3. mean       -media de valores
# 4. median     -mediana aritmetica de los valores
# 5. min        -minimo
# 6. max        -maximo
# 7. mode       -moda
# 8. std        -desviacion estandar insesgada
# 9. var        -varianza insesgada
# 10.quantile   -calculo estadistico basado en el rango de los elementos
# ```

# %%
df.shape
# Out:
# (360, 8)

# %%
#sum the values in a column
df['Interest Paid'].sum()
# Out:
# 207106.01

# %%
df.sum()
# Out:
# Month                                                           64980
# Starting Balance                                          82843130.97
# Repayment                                                    607111.2
# Interest Paid                                               207106.01
# Principal Paid                                              400005.19
# New Balance                                               82443125.78
# Mortgage Name       30 Year30 Year30 Year30 Year30 Year30 Year30 Y...
# Interest Rate                                                    10.8
# dtype: object

# %% [markdown]
# Cuando la variable no es numerica concatena las cadenas, como en Mortgage Name

# %% [markdown]
# # Estadisticas resumidas
#
# con df.describe() se obtiene las siguientes estadisticas resumidas:
#
# **la media, la desviacion estandar, el minimo, el maximo, y los percentiles numero 25, 50 y 75 para todas las columnas numericas.**

# %%
df.describe()
# Out:
#             Month  Starting Balance     Repayment  Interest Paid  \
# count  360.000000        360.000000  3.600000e+02     360.000000
# mean   180.500000     230119.808250  1.686420e+03     575.294472
# std    104.067286     114722.017993  2.276901e-13     286.805047
# min      1.000000       1677.040000  1.686420e+03       4.190000
# 25%     90.750000     136767.252500  1.686420e+03     341.910000
# 50%    180.500000     244736.870000  1.686420e+03     611.840000
# 75%    270.250000     331030.610000  1.686420e+03     827.575000
# max    360.000000     400000.000000  1.686420e+03    1000.000000
#
#        Principal Paid    New Balance  Interest Rate
# count      360.000000     360.000000   3.600000e+02
# mean      1111.125528  229008.682722   3.000000e-02
# std        286.805047  115008.823040   6.948551e-18
# min        686.420000      -5.190000   3.000000e-02
# 25%        858.845000  135422.742500   3.000000e-02
# 50%       1074.580000  243662.290000   3.000000e-02
# ...

# %% [markdown]
# # .round()para fijar cunatos decimales se quieren en el resultado.
#
# *Si prefieren tener menos precision en sus resultados y eliminar la notacion cientifica, pueden fijar cuantos lugares ocupar despues del decimal*

# %%
df.describe().round(2)
# Out:
#         Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# count  360.00            360.00     360.00         360.00          360.00
# mean   180.50         230119.81    1686.42         575.29         1111.13
# std    104.07         114722.02       0.00         286.81          286.81
# min      1.00           1677.04    1686.42           4.19          686.42
# 25%     90.75         136767.25    1686.42         341.91          858.84
# 50%    180.50         244736.87    1686.42         611.84         1074.58
# 75%    270.25         331030.61    1686.42         827.58         1344.51
# max    360.00         400000.00    1686.42        1000.00         1682.23
#
#        New Balance  Interest Rate
# count       360.00         360.00
# mean     229008.68           0.03
# std      115008.82           0.00
# min          -5.19           0.03
# 25%      135422.74           0.03
# 50%      243662.29           0.03
# 75%      330171.76           0.03
# ...

# %% [markdown]
# # Incluir todas ('all') las variables en el resultado de .describe()
#
# *Por defecto solo las variables numericas estan en la salida, para incluir todas debe usar:* **df.describe(include='all') tambien proporcionara el recuento de las columnas no numericas.**

# %%
df.describe(include='all').round(2)
# Out:
#          Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# count   360.00            360.00     360.00         360.00          360.00
# unique     NaN               NaN        NaN            NaN             NaN
# top        NaN               NaN        NaN            NaN             NaN
# freq       NaN               NaN        NaN            NaN             NaN
# mean    180.50         230119.81    1686.42         575.29         1111.13
# std     104.07         114722.02       0.00         286.81          286.81
# min       1.00           1677.04    1686.42           4.19          686.42
# 25%      90.75         136767.25    1686.42         341.91          858.84
# 50%     180.50         244736.87    1686.42         611.84         1074.58
# 75%     270.25         331030.61    1686.42         827.58         1344.51
# max     360.00         400000.00    1686.42        1000.00         1682.23
#
#         New Balance Mortgage Name  Interest Rate
# ...

# %% [markdown]
# **Especificar la salida a una columna en particular**

# %%
df['Starting Balance'].describe()
# Out:
# count       360.000000
# mean     230119.808250
# std      114722.017993
# min        1677.040000
# 25%      136767.252500
# 50%      244736.870000
# 75%      331030.610000
# max      400000.000000
# Name: Starting Balance, dtype: float64
